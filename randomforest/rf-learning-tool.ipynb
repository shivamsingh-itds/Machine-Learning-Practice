# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
     

X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)
     

df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.448968  0.413236  0.802569 -0.396930  1.195417       0
# 1  2.655331  1.675945 -0.352537 -0.301515 -0.755695       0
# 2 -1.011041 -2.463090  3.193075 -0.095288  0.248505       1
# 3  1.667692  1.245410  0.407564 -1.885051  1.590177       0
# 4  0.955398  1.123907  0.273556 -1.953520  1.650412       0
